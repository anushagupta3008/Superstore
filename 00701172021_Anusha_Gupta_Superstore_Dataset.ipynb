# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/superstore_dataset2011-2015.csv (6).zip",encoding='latin-1')

# %%
df
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #tells rows and columns
# Out:
# (51290, 24)

# %%
df.columns #gives column names
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
df.tail()
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# **Data Types**

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
df['Quantity']
# Out:
# 0        2
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 51285    2
# 51286    1
# 51287    3
# 51288    1
# 51289    3
# Name: Quantity, Length: 51290, dtype: int64

# %%
# converting string into datetime object.
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# ##1)BOXPLOT FOR ALL NUMERIC VARIABLES

# %%
sns.boxplot(data=df,orient="v",palette="Set2")
plt.show()
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
fig, axes = plt.subplots(figsize = (10 , 10))
sns.boxplot(df['Profit'])
plt.show()
df.Profit.describe()
# Out:
# count    51290.000000
# mean        28.610982
# std        174.340972
# min      -6599.978000
# 25%          0.000000
# 50%          9.240000
# 75%         36.810000
# max       8399.976000
# Name: Profit, dtype: float64

# %%
fig, axes = plt.subplots(figsize = (10 , 10))
sns.boxplot(df['Quantity'])
plt.show()
df.Quantity.describe()
# Out:
# count    51290.000000
# mean         3.476545
# std          2.278766
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max         14.000000
# Name: Quantity, dtype: float64

# %%
fig, axes = plt.subplots(figsize = (10 , 10))
sns.boxplot(df['Discount'])
plt.show()
df.Discount.describe()
# Out:
# count    51290.000000
# mean         0.142908
# std          0.212280
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.200000
# max          0.850000
# Name: Discount, dtype: float64

# %%
fig, axes = plt.subplots(figsize = (10 , 10))
sns.boxplot(d['shipping_cost'])
plt.show()
d.shipping_cost.describe()
# Out:
# count    51290.000000
# mean        26.375915
# std         57.296804
# min          0.000000
# 25%          2.610000
# 50%          7.790000
# 75%         24.450000
# max        933.570000
# Name: shipping_cost, dtype: float64

# %% [markdown]
# ##CHECK FOR OUTLIERS OF BOXPLOT

# %%
Q1 = df.quantile(q = 0.25, axis = 0, numeric_only = True, interpolation = 'linear')

Q3 = df.quantile(q = 0.75, axis = 0, numeric_only = True, interpolation = 'linear')

# %%
IQR = Q3 - Q1

print(IQR)
# Out:
# Row ID           25644.500000
# Postal Code      66785.000000
# Sales              220.294575
# Quantity             3.000000
# Discount             0.200000
# Profit              36.810000
# Shipping Cost       21.840000
# dtype: float64

# %% [markdown]
# ##2) PAIRPLOT FOR SALES,PROFIT,DISCOUNT,POSTAL CODE and QUANTITY *vs* REGION

# %%
a=df[['Sales','Profit','Discount','Postal Code','Quantity','Region']]

# %%
a
# Out:
#          Sales    Profit  Discount  Postal Code  Quantity   Region
# 0      408.300  106.1400       0.0          NaN         2   Africa
# 1      120.366   36.0360       0.1          NaN         3  Oceania
# 2       66.120   29.6400       0.0          NaN         4     EMEA
# 3       44.865  -26.0550       0.5          NaN         3    North
# 4      113.670   37.7700       0.1          NaN         5  Oceania
# ...        ...       ...       ...          ...       ...      ...
# 51285   13.904    4.5188       0.2      94533.0         2     West
# 51286    3.990    0.4200       0.0          NaN         1   Africa
# 51287   26.400   12.3600       0.0          NaN         3  Central
# 51288    7.120    0.5600       0.0          NaN         1    North
# 51289    3.024   -0.6048       0.2      80538.0         3     West
#
# [51290 rows x 6 columns]

# %%
sns.pairplot(a,hue="Region")
plt.plot()
# Out:
# []

# %% [markdown]
# ##3) Impact of sales through ship mode

# %%
df[['Sales','Ship Mode']]
# Out:
#          Sales       Ship Mode
# 0      408.300  Standard Class
# 1      120.366  Standard Class
# 2       66.120    Second Class
# 3       44.865    Second Class
# 4      113.670  Standard Class
# ...        ...             ...
# 51285   13.904  Standard Class
# 51286    3.990  Standard Class
# 51287   26.400    Second Class
# 51288    7.120  Standard Class
# 51289    3.024  Standard Class
#
# [51290 rows x 2 columns]

# %%
x=df['Ship Mode']
y=df['Sales']
sns.barplot(x, y)

# %% [markdown]
# As it is evident from above bar plot that there is not much impact of sales on different ship modes as these shipmodes have almost same value for sales.

# %% [markdown]
# #4) Segment wise sales and its impact.

# %%
df['Segment'].value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: Segment, dtype: int64

# %%
df['Sales'].value_counts()
# Out:
# 12.9600     66
# 25.9200     50
# 19.4400     43
# 32.4000     42
# 15.5520     41
#             ..
# 123.6534     1
# 31.9350      1
# 185.5980     1
# 71.2161      1
# 61.9740      1
# Name: Sales, Length: 22995, dtype: int64

# %%
x=df['Segment']
y=df['Sales']
sns.barplot(x, y)
plt.show()

# %% [markdown]
# As it is evident from above bar plot that there is not much impact of sales on different segments as these segments have almost same value for sales.

# %% [markdown]
# ##4) PLOT BAR PLOT AND FIND WHICH SEGMENT HAS HIGHEST SALES AND PROFIT

# %%
x=df['Segment']
y=df['Profit']
sns.barplot(x, y)
plt.show()

# %% [markdown]
# Home office segment has highest profit.

# %%
x=df['Segment']
y=df['Sales']
sns.barplot(x, y)
plt.show()

# %% [markdown]
# Home office and corporate have highest sales

# %% [markdown]
# ##5) Create bar plot for subcategory wise order counts.Which sub-category wise has naximum and minimum order counts.

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(10,6))

df['Sub-Category'].value_counts().plot(kind='bar')

# %% [markdown]
# As evident from bar plot that Binders has highest and tables has lowest subcategory wise order counts.

# %% [markdown]
# ##6) Analyze the city-wise performace of order counts.

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Santo Domingo    443
#                 ...
# Melitopol'         1
# Terneuzen          1
# Athis-Mons         1
# Yuyao              1
# Deer Park          1
# Name: City, Length: 3636, dtype: int64

# %%
plt.figure(figsize=(25,20))
sns.countplot(df['City'])

# %% [markdown]
# By analyzing ,  new york city has highest order counts and deer park has lowest order counts.

# %% [markdown]
# ##7) Analyze the state-wise performace of order counts.

# %%
df['State'].value_counts()
# Out:
# California       2001
# England          1499
# New York         1128
# Texas             985
# Ile-de-France     981
#                  ...
# Arad                1
# Edirne              1
# Kastamonu           1
# Gangwon             1
# Inhambane           1
# Name: State, Length: 1094, dtype: int64

# %%
plt.figure(figsize=(25,20))
sns.countplot(df['State'])

# %% [markdown]
# By analyzing ,  california has highest order counts and inhambane has lowest order counts.

# %% [markdown]
# ## 8) Analyze category wise sales performance and sub category wise profit performance. Which shipment class boosts the sales of which category.

# %%
x=df['Category']
y=df['Sales']
sns.barplot(x, y)
plt.show()

# %% [markdown]
# Technology has highest sales and office supplies has lowest sales.

# %%
plt.figure(figsize=(17,10))
x=df['Sub-Category']
y=df['Profit']
sns.barplot(x, y)
plt.show()

# %% [markdown]
# Copiers has highest profit and tables has highest loss.

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: Category, dtype: int64

# %%
df1=df[df['Category']=='Technology']
df1
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6       21613   IN-2011-30733 2011-01-02 2011-03-02    Second Class
# 15       8484  US-2011-118892 2011-01-02 2011-06-02  Standard Class
# 25      48599    UP-2011-3730 2011-01-03 2011-05-03  Standard Class
# 31      21917   IN-2011-59986 2011-01-03 2011-03-03     First Class
# 33      48595    UP-2011-3730 2011-01-03 2011-05-03  Standard Class
# ...       ...             ...        ...        ...             ...
# 51256   32204  CA-2014-143259 2014-12-31 2015-04-01  Standard Class
# 51259    1786  MX-2014-116267 2014-12-31 2015-03-01    Second Class
# 51263    8855  MX-2014-110527 2014-12-31 2015-02-01    Second Class
# 51274   41743    TU-2014-5170 2014-12-31 2015-04-01    Second Class
# 51275   28569   ID-2014-54442 2014-12-31 2015-04-01  Standard Class
#
#       Customer ID      Customer Name    Segment           City  \
# 6        PO-18865  Patrick O'Donnell   Consumer          Dhaka
# ...

# %%
df1['Ship Mode'].value_counts()
# Out:
# Standard Class    6117
# Second Class      2030
# First Class       1476
# Same Day           518
# Name: Ship Mode, dtype: int64

# %% [markdown]
# As it is evident from df1 values counts that technology boosts the sales of standard class the most.

# %%
df2=df[df['Category']=='Furniture']
df2
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 4       22255    IN-2011-47883 2011-01-01 2011-08-01  Standard Class
# 7       34662   CA-2011-115161 2011-01-02 2011-03-02     First Class
# 12      41445     IR-2011-6550 2011-01-02 2011-06-02  Standard Class
# 24      13130  ES-2011-1705541 2011-01-03 2011-06-03  Standard Class
# 27      37844   CA-2011-113880 2011-01-03 2011-05-03  Standard Class
# ...       ...              ...        ...        ...             ...
# 51242    7199   MX-2014-141712 2014-12-31 2014-12-31        Same Day
# 51246   12928  ES-2014-3458802 2014-12-31 2015-05-01  Standard Class
# 51249   41744     TU-2014-5170 2014-12-31 2015-04-01    Second Class
# 51255   44026     RS-2014-1460 2014-12-31 2015-02-01    Second Class
# 51269   23681    IN-2014-75603 2014-12-31 2015-05-01    Second Class
#
#       Customer ID      Customer Name      Segment           City  \
# 4        JH-15985        Joseph Holt     Consumer    Wagga Wagga
# ...

# %%
df2['Ship Mode'].value_counts()
# Out:
# Standard Class    5969
# Second Class      1968
# First Class       1431
# Same Day           508
# Name: Ship Mode, dtype: int64

# %% [markdown]
# As it is evident from df1 values counts that furniture boosts the sales of standard class the most.

# %%
df3=df[df['Category']=='Office Supplies']
df3
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040 2011-01-01 2011-06-01  Standard Class
# 1       22253    IN-2011-47883 2011-01-01 2011-08-01  Standard Class
# 2       48883     HU-2011-1220 2011-01-01 2011-05-01    Second Class
# 3       11731  IT-2011-3647632 2011-01-01 2011-05-01    Second Class
# 5       22254    IN-2011-47883 2011-01-01 2011-08-01  Standard Class
# ...       ...              ...        ...        ...             ...
# 51285   32593   CA-2014-115427 2014-12-31 2015-04-01  Standard Class
# 51286   47594     MO-2014-2560 2014-12-31 2015-05-01  Standard Class
# 51287    8857   MX-2014-110527 2014-12-31 2015-02-01    Second Class
# 51288    6852   MX-2014-114783 2014-12-31 2015-06-01  Standard Class
# 51289   36388   CA-2014-156720 2014-12-31 2015-04-01  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %%
df3['Ship Mode'].value_counts()
# Out:
# Standard Class    18689
# Second Class       6311
# First Class        4598
# Same Day           1675
# Name: Ship Mode, dtype: int64

# %% [markdown]
# As it is evident from df1 values counts that office supplies boosts the sales of standard class the most.

# %% [markdown]
# And also by analyzing df1, df2 and df3 we saw that among all shipmodes , office supplies boost the sales of standard class the most.
